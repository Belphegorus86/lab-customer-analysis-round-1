# %%
import pandas as pd

# %%
csv1 = pd.read_csv("https://raw.githubusercontent.com/Belphegorus86/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file1.csv")
csv2 = pd.read_csv("https://raw.githubusercontent.com/Belphegorus86/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file2.csv")
csv3 = pd.read_csv("https://raw.githubusercontent.com/Belphegorus86/lab-customer-analysis-round-1/master/files_for_lab/csv_files/file3.csv")

# %%
csv1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
csv1.shape, csv2.shape, csv3.shape
# Out:
# ((4008, 11), (996, 11), (7070, 11))

# %%
csv1 = csv1.drop_duplicates()
csv1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
# 1071      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
csv1.columns = csv1.columns.str.lower().str.replace('state', 'st').str.replace('_', ' ')
csv2.columns = csv2.columns.str.lower().str.replace('state', 'st').str.replace('_', ' ')
csv3.columns = csv3.columns.str.lower().str.replace('state', 'st').str.replace('_', ' ')

# %%
csv1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
# 1071      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
csv1 = csv1[["customer", "st", "gender", "education", "customer lifetime value", "income", "monthly premium auto", "number of open complaints", "policy type", "vehicle class", "total claim amount"]]
csv2 = csv2[["customer", "st", "gender", "education", "customer lifetime value", "income", "monthly premium auto", "number of open complaints", "policy type", "vehicle class", "total claim amount"]]
csv3 = csv3[["customer", "st", "gender", "education", "customer lifetime value", "income", "monthly premium auto", "number of open complaints", "policy type", "vehicle class", "total claim amount"]]

# %%
csv1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
# 1071      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
csv2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
csv3
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
concatcsv = pd.concat([csv1, csv2, csv3], axis=0, ignore_index=True)

# %%
concatcsv
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9133  LA72316  California      M              Bachelor
# 9134  PK87824  California      F               College
# 9135  TD14365  California      M              Bachelor
# 9136  UP19263  California      M               College
# 9137  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
num_cols = concatcsv._get_numeric_data()

# %%
num_cols
#by omission the rest of the column should be categorical
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 9133  71941.0                  73.0          198.234764
# 9134  21604.0                  79.0          379.200000
# 9135      0.0                  85.0          790.784983
# 9136  21941.0                  96.0          691.200000
# 9137      0.0                  77.0          369.600000
#
# [9138 rows x 3 columns]

# %%
concatcsv = concatcsv.drop(['education', 'number of open complaints'], axis=1)

# %%
concatcsv
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 9133  LA72316  California      M             23405.98798  71941.0
# 9134  PK87824  California      F             3096.511217  21604.0
# 9135  TD14365  California      M             8163.890428      0.0
# 9136  UP19263  California      M             7524.442436  21941.0
# 9137  Y167826  California      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

def remove_percent(value):
    return value.rstrip('%') if isinstance(value, str) else value

concatcsv["customer lifetime value"] = concatcsv["customer lifetime value"].apply(remove_percent)
concatcsv["customer lifetime value"] = pd.to_numeric(concatcsv["customer lifetime value"], errors='coerce')

# Multiply by 100
concatcsv["customer lifetime value"] *= 100

# %%
concatcsv
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN     0.00
# 1     QZ44356     Arizona      F              69795359.00     0.00
# 2     AI49188      Nevada      F             128874317.00 48767.00
# 3     WW63253  California      M              76458618.00     0.00
# 4     GA49547  Washington      M              53630765.00 36357.00
# ...       ...         ...    ...                      ...      ...
# 9133  LA72316  California      M               2340598.80 71941.00
# 9134  PK87824  California      F                309651.12 21604.00
# 9135  TD14365  California      M                816389.04     0.00
# 9136  UP19263  California      M                752444.24 21941.00
# 9137  Y167826  California      M                261183.69     0.00
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                  1000.00   Personal Auto  Four-Door Car                2.70
# ...

# %%
finalcsv = concatcsv.drop_duplicates()
finalcsv
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN     0.00
# 1     QZ44356     Arizona      F            6979535900.00     0.00
# 2     AI49188      Nevada      F           12887431700.00 48767.00
# 3     WW63253  California      M            7645861800.00     0.00
# 4     GA49547  Washington      M            5363076500.00 36357.00
# ...       ...         ...    ...                      ...      ...
# 9133  LA72316  California      M             234059879.80 71941.00
# 9134  PK87824  California      F              30965112.17 21604.00
# 9135  TD14365  California      M              81638904.28     0.00
# 9136  UP19263  California      M              75244424.36 21941.00
# 9137  Y167826  California      M              26118368.66     0.00
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                  1000.00   Personal Auto  Four-Door Car                2.70
# ...
